# %%
import requests as req
from bs4 import BeautifulSoup as bs


ln  =req.get('https://www.lanacion.com.ar/')
ln
# Out:
# <Response [200]>

# %%
ln.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="es">\r\n<head>\r\n\r\n\r\n<script>\r\n    \r\n    \r\n    var varnish = [\'\'];\r\n\r\n    Array.from = Array.from || (function () { var a = Object.prototype.toString, b = function (f) { return \'function\' == typeof f || \'[object Function]\' === a.call(f) }, c = function (f) { var g = +f; return isNaN(g) ? 0 : 0 != g && isFinite(g) ? (0 < g ? 1 : -1) * Math.floor(Math.abs(g)) : g }, d = Math.pow(2, 53) - 1, e = function (f) { var g = c(f); return Math.min(Math.max(g, 0), d) }; return function (g) { var h = this, i = Object(g); if (null == g) throw new TypeError(\'Array.from requires an array-like object - not null or undefined\'); var l, j = 1 < arguments.length ? arguments[1] : void 0; if (\'undefined\' != typeof j) { if (!b(j)) throw new TypeError(\'Array.from: when provided, the second argument must be a function\'); 2 < arguments.length && (l = arguments[2]) } for (var p, m = e(i.length), n = b(h) ? Object(new h(m)) : Array(m), o = 0; o < m;)p = i[o], n[o] = j ? \'undefined\' == typeof l ? j(p, o) : j.call(l, p, o) : p, o += 1; return n.length = m, n } }());\r\n\r\n    let metaRefresh = localStorage.getItem("CDmetaRefresh");\r\n    let countNotas = localStorage.getItem("countNotas");\r\n   \r\n\r\n    metaRefresh = metaRefresh != null ? "yes" : "no";\r\n    countNotas = countNotas ? countNotas : 0;\r\n\r\n    if (metaRefresh === "yes") {\r\n        localStorage.removeItem("CDmetaRefresh");\r\n    }\r\n\r\n    var dataLayer = [\r\n        {\r\n            "metarefresh": metaRefresh,\r\n            "pageType": "home",\r\n            "nota-pos": \'home\' === \'nota\' ? "," + countNotas : \'N/A\',\r\n            "valor": "N/A",\r\n            "TeaserPremium": ""\r\n        }\r\n    ];\r\n\r\n    \r\n    dataLayer[0].front = varnish[0] || "N/A";\r\n    dataLayer[0].host = varnish[1] || "N/A";\r\n    dataLayer[0].cache = "LNC-FRONT08";\r\n    dataLayer[0].build = "9.0.21040-HEAD-d601236df";\r\n    \r\n\r\n   \r\n    if(\'home\' === "nota"){\r\n        dataLayer[0].notasLeidas = countNotas;\r\n        // dataLayer[0].countNotas = countNotas;\r\n    }\r\n</script>\r\n\r\n\r\n    <link href="/favicon.ico" rel="icon" type="image/x-icon">\r\n    <meta charset="UTF-8" name="viewport" content="width=device-width, initial-scale=1">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    \r\n<meta name="theme-color" content="#ffffff">\r\n<link rel="manifest" href="/manifest.json">\r\n    <link rel="dns-prefetch" href="//static.glanacion.com">\r\n<link rel="dns-prefetch" href="//cdn.livefyre.com">\r\n<link rel="dns-prefetch" href="//bucket.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket1.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket2.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket3.glanacion.com">\r\n<link rel="dns-prefetch" href="//ingresar.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-ingresar.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-paywall.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//wsresultados.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-contenidos.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//contenidos.lanacion.com.ar">\r\n    <meta name="msApplication-ID" content="width=device-width,initial-scale=1,minimum-scale=1">\r\n    <meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1">\r\n    <meta name="copyright" content="LA NACION">\r\n    <meta name="title" content="\xc3\x9altimas noticias de Argentina y el mundo - LA NACION">\r\n    <meta name="description" content="LA NACION - Informaci\xc3\xb3n confiable en Internet. Noticias de Argentina y del mundo - \xc2\xa1Informate ya!">\r\n    <meta name="keywords" content="la naci\xc3\xb3n, diario, argentina, noticias, informaci\xc3\xb3n, pol\xc3\xadtica, econom\xc3\xada, finanzas, deportes, futbol, tenis, rugby, basquetbol, voleibol, formula 1, cultura, espect\xc3\xa1culos, cine, teatro, televisi\xc3\xb3n, humor, juegos, h ...

# %%
ln.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="es">\r\n<head>\r\n\r\n\r\n<script>\r\n    \r\n    \r\n    var varnish = [\'\'];\r\n\r\n    Array.from = Array.from || (function () { var a = Object.prototype.toString, b = function (f) { return \'function\' == typeof f || \'[object Function]\' === a.call(f) }, c = function (f) { var g = +f; return isNaN(g) ? 0 : 0 != g && isFinite(g) ? (0 < g ? 1 : -1) * Math.floor(Math.abs(g)) : g }, d = Math.pow(2, 53) - 1, e = function (f) { var g = c(f); return Math.min(Math.max(g, 0), d) }; return function (g) { var h = this, i = Object(g); if (null == g) throw new TypeError(\'Array.from requires an array-like object - not null or undefined\'); var l, j = 1 < arguments.length ? arguments[1] : void 0; if (\'undefined\' != typeof j) { if (!b(j)) throw new TypeError(\'Array.from: when provided, the second argument must be a function\'); 2 < arguments.length && (l = arguments[2]) } for (var p, m = e(i.length), n = b(h) ? Object(new h(m)) : Array(m), o = 0; o < m;)p = i[o], n[o] = j ? \'undefined\' == typeof l ? j(p, o) : j.call(l, p, o) : p, o += 1; return n.length = m, n } }());\r\n\r\n    let metaRefresh = localStorage.getItem("CDmetaRefresh");\r\n    let countNotas = localStorage.getItem("countNotas");\r\n   \r\n\r\n    metaRefresh = metaRefresh != null ? "yes" : "no";\r\n    countNotas = countNotas ? countNotas : 0;\r\n\r\n    if (metaRefresh === "yes") {\r\n        localStorage.removeItem("CDmetaRefresh");\r\n    }\r\n\r\n    var dataLayer = [\r\n        {\r\n            "metarefresh": metaRefresh,\r\n            "pageType": "home",\r\n            "nota-pos": \'home\' === \'nota\' ? "," + countNotas : \'N/A\',\r\n            "valor": "N/A",\r\n            "TeaserPremium": ""\r\n        }\r\n    ];\r\n\r\n    \r\n    dataLayer[0].front = varnish[0] || "N/A";\r\n    dataLayer[0].host = varnish[1] || "N/A";\r\n    dataLayer[0].cache = "LNC-FRONT08";\r\n    dataLayer[0].build = "9.0.21040-HEAD-d601236df";\r\n    \r\n\r\n   \r\n    if(\'home\' === "nota"){\r\n        dataLayer[0].notasLeidas = countNotas;\r\n        // dataLayer[0].countNotas = countNotas;\r\n    }\r\n</script>\r\n\r\n\r\n    <link href="/favicon.ico" rel="icon" type="image/x-icon">\r\n    <meta charset="UTF-8" name="viewport" content="width=device-width, initial-scale=1">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    \r\n<meta name="theme-color" content="#ffffff">\r\n<link rel="manifest" href="/manifest.json">\r\n    <link rel="dns-prefetch" href="//static.glanacion.com">\r\n<link rel="dns-prefetch" href="//cdn.livefyre.com">\r\n<link rel="dns-prefetch" href="//bucket.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket1.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket2.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket3.glanacion.com">\r\n<link rel="dns-prefetch" href="//ingresar.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-ingresar.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-paywall.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//wsresultados.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-contenidos.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//contenidos.lanacion.com.ar">\r\n    <meta name="msApplication-ID" content="width=device-width,initial-scale=1,minimum-scale=1">\r\n    <meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1">\r\n    <meta name="copyright" content="LA NACION">\r\n    <meta name="title" content="Últimas noticias de Argentina y el mundo - LA NACION">\r\n    <meta name="description" content="LA NACION - Información confiable en Internet. Noticias de Argentina y del mundo - ¡Informate ya!">\r\n    <meta name="keywords" content="la nación, diario, argentina, noticias, información, política, economía, finanzas, deportes, futbol, tenis, rugby, basquetbol, voleibol, formula 1, cultura, espectáculos, cine, teatro, televisión, humor, juegos, horóscopo, clima, pronostico, mapa, vinos, restaurantes, quiniela ...

# %%
sopa=bs(ln.content)
# sopa

# %%
sopa.find(["h2",'h1'])
# Out:
# <h1 class="com-title">
# <a href="/politica/la-corte-dejo-firme-condena-boudou-caso-nid2528946" title="La Corte dejó firme la condena contra Boudou y regresaría a prisión">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Ciccone.</em>
#         La Corte dejó firme la condena contra Boudou y regresaría a prisión
#     </a>
# </h1>

# %%
tit = sopa.find_all(["h2",'h1'])

# %%
urls = []
for h in tit:
    urls.append(h.find('a').attrs['href'])
i = 0
for link in urls:
  urls[i] = "www.lanacion.com" + urls[i]
  i = i + 1
urls
# Out:
# ['www.lanacion.com/politica/la-corte-dejo-firme-condena-boudou-caso-nid2528946',
#  'www.lanacion.com/politica/amado-boudou-no-es-carlos-menem-es-nid2528977',
#  'www.lanacion.com/economia/campo/vicentin-juez-ordeno-intervencion-conduccion-empresa-nid2528958',
#  'www.lanacion.com/sociedad/quien-era-alejandro-hakim-medico-murio-protesta-nid2528938',
#  'www.lanacion.com/economia/negocios/solways-quiebra-agencia-turismo-mayorista-pone-riesgo-nid2528893',
#  'www.lanacion.com/economia/con-50000-convirtieron-su-hobby-negocio-exitoso-nid2519851']

# %%
len(tit)
# Out:
# 6

# %%
def LN():
  for x in range(0,len(tit)):
      print(tit[x].get_text(strip=True))

LN()

# %%
def LNlist():
  list = []
  for x in range(0,len(tit)):
      list.append(tit[x].get_text(strip=True))
  return list

LNlist()
# Out:
# ['Ciccone.La Corte dejó firme la condena contra Boudou y regresaría a prisión',
#  'Análisis.Boudou no es Menem, es María Julia',
#  'Vicentin.El juez ordenó la intervención de la conducción de la cerealera',
#  'Perfil.Quién era Alejandro Hakim, el médico que murió en la protesta',
#  'Solways.Quiebra un mayorista de turismo y pone en riesgo a 47 agencias',
#  'Con $50.000.Hicieron de su hobby un negocio exitoso que exporta a EE. UU.']

# %%
def LNlist():
  list = []
  for x in range(0,len(tit)):
      list.append(tit[x].get_text(strip=True))

  return list

LNlist()

# %%
list = []
for x in range(0,len(tit)):
      list.append(tit[x].get_text(strip=True))
list
# Out:
# ['Ciccone.La Corte dejó firme la condena contra Boudou y regresaría a prisión',
#  'Análisis.Boudou no es Menem, es María Julia',
#  'Vicentin.El juez ordenó la intervención de la conducción de la cerealera',
#  'Perfil.Quién era Alejandro Hakim, el médico que murió en la protesta',
#  'Solways.Quiebra un mayorista de turismo y pone en riesgo a 47 agencias',
#  'Con $50.000.Hicieron de su hobby un negocio exitoso que exporta a EE. UU.']

# %%
urls = []
for h in tit:
    urls.append(h.find('a').attrs['href'])
i = 0
for link in urls:
  urls[i] = "www.lanacion.com" + urls[i]
  i = i + 1
urls
# Out:
# ['www.lanacion.com/politica/la-corte-dejo-firme-condena-boudou-caso-nid2528946',
#  'www.lanacion.com/politica/amado-boudou-no-es-carlos-menem-es-nid2528977',
#  'www.lanacion.com/economia/campo/vicentin-juez-ordeno-intervencion-conduccion-empresa-nid2528958',
#  'www.lanacion.com/sociedad/quien-era-alejandro-hakim-medico-murio-protesta-nid2528938',
#  'www.lanacion.com/economia/negocios/solways-quiebra-agencia-turismo-mayorista-pone-riesgo-nid2528893',
#  'www.lanacion.com/economia/con-50000-convirtieron-su-hobby-negocio-exitoso-nid2519851']

# %%
i = 0
for link2 in list:
  list[i] = list[i] + ' Link->' + urls[i]
  i = i + 1

list

# %%
def LNlist_link():
  urls = []
  list = []
  for x in range(0,len(tit)):
      list.append(tit[x].get_text(strip=True))
  for h in tit:
      urls.append(h.find('a').attrs['href'])
  i = 0
  for link in urls:
    urls[i] = "www.lanacion.com" + urls[i]
    i = i + 1
  i = 0
  for link2 in list:
    list[i] = list[i] + ' Leela en ' + urls[i]
    i = i + 1
  return(list)

LNlist_link()
# Out:
# ['Ciccone.La Corte dejó firme la condena contra Boudou y regresaría a prisión Leela en www.lanacion.com/politica/la-corte-dejo-firme-condena-boudou-caso-nid2528946',
#  'Análisis.Boudou no es Menem, es María Julia Leela en www.lanacion.com/politica/amado-boudou-no-es-carlos-menem-es-nid2528977',
#  'Vicentin.El juez ordenó la intervención de la conducción de la cerealera Leela en www.lanacion.com/economia/campo/vicentin-juez-ordeno-intervencion-conduccion-empresa-nid2528958',
#  'Perfil.Quién era Alejandro Hakim, el médico que murió en la protesta Leela en www.lanacion.com/sociedad/quien-era-alejandro-hakim-medico-murio-protesta-nid2528938',
#  'Solways.Quiebra un mayorista de turismo y pone en riesgo a 47 agencias Leela en www.lanacion.com/economia/negocios/solways-quiebra-agencia-turismo-mayorista-pone-riesgo-nid2528893',
#  'Con $50.000.Hicieron de su hobby un negocio exitoso que exporta a EE. UU. Leela en www.lanacion.com/economia/con-50000-convirtieron-su-hobby-negocio-exitoso-nid2519851']
