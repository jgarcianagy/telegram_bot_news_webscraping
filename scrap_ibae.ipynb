# %%
import requests as req
from bs4 import BeautifulSoup as bs


ibae  =req.get('https://www.infobae.com/')
ibae
# Out:
# <Response [200]>

# %%
ibae.content
# Out:
# b'<!DOCTYPE html><html lang="es"><head><title>Am\xc3\xa9rica: hacemos periodismo - Infobae</title><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta charSet="UTF-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.5, maximum-scale=2.0"/><link rel="canonical" href="https://www.infobae.com/america/"/><meta property="keywords" content="Infobae, infobae america, Infobae.com, ultimas noticias, noticias de hoy, noticias, \xc3\xbaltima hora, actualidad, internacional, Am\xc3\xa9rica, Europa, \xc3\x81sia, \xc3\x81frica, Ocean\xc3\xada, pol\xc3\xadtica, econom\xc3\xada, deportes, cultura, sociedad, tecnolog\xc3\xada, M\xc3\xa9xico, Brasil, Colombia, Argentina, Chile, Venezuela, Ecuador, Per\xc3\xba, Cuba, noticias de brasil,noticias de peru,latinoamerica,noticias de argentina,america latina,noticias de ecuador,noticias de mexico,imagenes de latinoamerica ,noticias de venezuela,noticias de america latina,noticias de chile,videos de latinoamerica,noticias de colombia, cubanos, Venezolanos, Am\xc3\xa9rica Latina, latinos, hispanos, espa\xc3\xb1ol, noticias, noticias en espa\xc3\xb1ol, noticias de latinoamerica, latinoamericanos,, Venezuela,, Cuba,, noticias,, hispanos,, Am\xc3\xa9rica, Latina,, cubanos,, venezolanos,, noticias, locales,, noticias, de, Cuba,, noticias, de, Venezuela,, noticias, de, Colombia, Miami, Cuba, noticias, Florida, Am\xc3\xa9rica Latina, Miami, Broward, latinos, hispanos, cubanos, venezolanos, eeuu, estados unidos, noticias nacionales estados unidos, econom\xc3\xada, finanzas,noticias,noticias internacionales,mundo,educacion,elecciones 2016,entretenimiento,musica,negocios,politica,salud, casa blanca, obama, washington, elecciones, mundo, fotos,entretenimiento, videos paparazzi, chismes de la far\xc3\xa1ndula hispana e internacional, cultura, opinion, deportes, Premier League, Liga BBVA, Serie A, Bundesliga, F\xc3\xbatbol, MLS, NASL, NFL, MLB, NBA, motor, v\xc3\xaddeos, fotos"/><meta name="description" content="Todas las noticias de Am\xc3\xa9rica Latina, Estados Unidos y el mundo en tiempo real. Ent\xc3\xa9rate de las noticias y sucesos m\xc3\xa1s importantes a nivel mundial, videos y fotos sobre los hechos y los protagonistas m\xc3\xa1s relevantes. L\xc3\xa9elo antes en Infobae."/><meta name="robots" content="index, follow"/><meta name="distribution" content="global"/><meta name="rating" content="general"/><meta name="language" content="es_ES"/><meta name="news_keywords" content=""/><meta property="article:tag" content=""/><meta property="article:section" content=""/><meta name="twitter:title" content="Am\xc3\xa9rica: hacemos periodismo"/><meta name="twitter:site" content="@infobae"/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:creator" content="@infobae"/><meta name="twitter:image" content="https://www.infobae.com/pf/resources/images/fallback-promo-image.png?d=444"/><meta name="twitter:description" content="Todas las noticias de Am\xc3\xa9rica Latina, Estados Unidos y el mundo en tiempo real. Ent\xc3\xa9rate de las noticias y sucesos m\xc3\xa1s importantes a nivel mundial, videos y fotos sobre los hechos y los protagonistas m\xc3\xa1s relevantes. L\xc3\xa9elo antes en Infobae."/><meta property="og:title" content="Am\xc3\xa9rica: hacemos periodismo"/><meta property="og:description" content="Todas las noticias de Am\xc3\xa9rica Latina, Estados Unidos y el mundo en tiempo real. Ent\xc3\xa9rate de las noticias y sucesos m\xc3\xa1s importantes a nivel mundial, videos y fotos sobre los hechos y los protagonistas m\xc3\xa1s relevantes. L\xc3\xa9elo antes en Infobae."/><meta property="og:url" content="https://www.infobae.com/america/"/><meta property="og:type" content="website"/><meta property="og:site_name" content="infobae"/><meta property="og:locale" content="es_LA"/><meta property="og:image" itemProp="image" content="https://www.infobae.com/pf/resources/images/fallback-promo-image.png?d=444"/><meta property="fb: ...

# %%
ibae.text
# Out:
# '<!DOCTYPE html><html lang="es"><head><title>América: hacemos periodismo - Infobae</title><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta charSet="UTF-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.5, maximum-scale=2.0"/><link rel="canonical" href="https://www.infobae.com/america/"/><meta property="keywords" content="Infobae, infobae america, Infobae.com, ultimas noticias, noticias de hoy, noticias, última hora, actualidad, internacional, América, Europa, Ásia, África, Oceanía, política, economía, deportes, cultura, sociedad, tecnología, México, Brasil, Colombia, Argentina, Chile, Venezuela, Ecuador, Perú, Cuba, noticias de brasil,noticias de peru,latinoamerica,noticias de argentina,america latina,noticias de ecuador,noticias de mexico,imagenes de latinoamerica ,noticias de venezuela,noticias de america latina,noticias de chile,videos de latinoamerica,noticias de colombia, cubanos, Venezolanos, América Latina, latinos, hispanos, español, noticias, noticias en español, noticias de latinoamerica, latinoamericanos,, Venezuela,, Cuba,, noticias,, hispanos,, América, Latina,, cubanos,, venezolanos,, noticias, locales,, noticias, de, Cuba,, noticias, de, Venezuela,, noticias, de, Colombia, Miami, Cuba, noticias, Florida, América Latina, Miami, Broward, latinos, hispanos, cubanos, venezolanos, eeuu, estados unidos, noticias nacionales estados unidos, economía, finanzas,noticias,noticias internacionales,mundo,educacion,elecciones 2016,entretenimiento,musica,negocios,politica,salud, casa blanca, obama, washington, elecciones, mundo, fotos,entretenimiento, videos paparazzi, chismes de la farándula hispana e internacional, cultura, opinion, deportes, Premier League, Liga BBVA, Serie A, Bundesliga, Fútbol, MLS, NASL, NFL, MLB, NBA, motor, vídeos, fotos"/><meta name="description" content="Todas las noticias de América Latina, Estados Unidos y el mundo en tiempo real. Entérate de las noticias y sucesos más importantes a nivel mundial, videos y fotos sobre los hechos y los protagonistas más relevantes. Léelo antes en Infobae."/><meta name="robots" content="index, follow"/><meta name="distribution" content="global"/><meta name="rating" content="general"/><meta name="language" content="es_ES"/><meta name="news_keywords" content=""/><meta property="article:tag" content=""/><meta property="article:section" content=""/><meta name="twitter:title" content="América: hacemos periodismo"/><meta name="twitter:site" content="@infobae"/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:creator" content="@infobae"/><meta name="twitter:image" content="https://www.infobae.com/pf/resources/images/fallback-promo-image.png?d=444"/><meta name="twitter:description" content="Todas las noticias de América Latina, Estados Unidos y el mundo en tiempo real. Entérate de las noticias y sucesos más importantes a nivel mundial, videos y fotos sobre los hechos y los protagonistas más relevantes. Léelo antes en Infobae."/><meta property="og:title" content="América: hacemos periodismo"/><meta property="og:description" content="Todas las noticias de América Latina, Estados Unidos y el mundo en tiempo real. Entérate de las noticias y sucesos más importantes a nivel mundial, videos y fotos sobre los hechos y los protagonistas más relevantes. Léelo antes en Infobae."/><meta property="og:url" content="https://www.infobae.com/america/"/><meta property="og:type" content="website"/><meta property="og:site_name" content="infobae"/><meta property="og:locale" content="es_LA"/><meta property="og:image" itemProp="image" content="https://www.infobae.com/pf/resources/images/fallback-promo-image.png?d=444"/><meta property="fb:app_id" content="303536999846097"/><meta property="fb:pages" content="34839376970"/><meta property="fb:pages" content="436205896728888"/><meta property="fb:pages" content="142361755806396"/><meta name="isDFP" content="true"/><meta name="dfpPageType" content="h ...

# %%
sopa=bs(ibae.content)
# sopa

# %%
sopa.find(['h2'])
# Out:
# <h2 class=" headline-title font_size_42 line_height_45" style="border:bottom"><a href="/america/eeuu/2020/12/01/eeuu-pidio-a-sus-ciudadanos-que-eviten-viajar-a-mexico-ante-el-fuerte-aumento-de-contagios-de-covid-19/">EEUU pidió a sus ciudadanos que eviten viajar a México, ante el fuerte aumento de contagios de COVID-19</a></h2>

# %%
tit = sopa.find_all(['h2','h1'])

# %%
len(tit)
# Out:
# 91

# %%
# tit

# %%
tit[0].get_text(strip=True)
# Out:
# 'EEUU pidió a sus ciudadanos que eviten viajar a México, ante el fuerte aumento de contagios de COVID-19'

# %%
def ibae():
  for x in range(0,len(tit)):
      print(tit[x].get_text(strip=True))

# %%
ibae()
# Out:
# ['EEUU pidió a sus ciudadanos que eviten viajar a México, ante el fuerte aumento de contagios de COVID-19',
#  'Por primera vez en la historia, el 50% de la publicidad fue destinada a medios digitales',
#  'De Ellen Page a Elliot: se hizo célebre por la película "Juno" y acaba de anunciar que es trans',
#  'Boris Johnson enfrenta una rebelión parlamentaria por las restricciones en el Reino Unido para frenar el covid-19',
#  'Un conductor embistió con su vehículo a los transeúntes de una calle peatonal en Alemania: 4 muertos, entre ellos un bebé',
#  'Arabia Saudita autorizó que los aviones comerciales israelíes utilicen su espacio aéreo en vuelo hacia Emiratos Árabes Unidos',
#  'Hugh Grant confesó por qué Hollywood le cerró las puertas por casi una década: “Hice el tonto en una película”',
#  'Un youtuber saltó de un puente para sumar seguidores en su canal y terminó con el cráneo fracturado',
#  'Asedio en la puerta de su casa, llamados permanentes y críticas: la pesadilla que vive el dueño de la camiseta que usó Maradona ante Inglaterra en el ’86',
#  'La monumental caricatura del dibujante inglés David Squires que rinde tributo a Maradona: Fiorito, la gloria, el ocaso y la eternidad',
#  'El regalo que guardará por siempre y la última conversación que tuvieron: las emotivas palabras de Ronaldo tras la muerte de Maradona',
#  'Los archivos de Wuhan: cómo el régimen chino ocultó el impacto del coronavirus en el inicio de la pandemia',
#  'Conmoción en Houston: hallaron muerta a la influencer de Instagram Alexis Sharkey',
#  'Insólito combate de MMA en Rusia: una luchadora venció por nocaut a un youtuber de 240 kilos',
#  'Wall Street inicia diciembre con una sólida alza tras cerrar su mejor mes desde 1987',
#  'Real Madrid cae ante el Shakhtar en Ucrania y pone en peligro su clasificación',
#  'Caso Ahmadreza Djalali: el régimen de Irán se prepara para ejecutar a un experto en medicina',
#  'Un fisicoculturista ruso se casó con su muñeca sexual: “Nuestro romance floreció durante la cuarentena”',
#  'Pfizer solicitó a la Unión Europea la autorización de emergencia para su vacuna contra el coronavirus',
#  'Dos conductas que la OMS desaconsejó de cara a las Fiestas de fin de año',
#  'La historia detrás del abrazo de un médico a un desconsolado paciente de covid-19 que conmovió a EEUU en el Día de Acción de Gracias',
#  'Director de Operaciones Técnicas de Moderna: “Vamos a llevar la vacuna a donde se necesite”',
#  'Coronavirus: 16 certezas que hoy tienen los médicos y es importante conocer',
#  '\ufeffKim Jong-un, su familia y los funcionarios de alto rango de Corea del Norte ya recibieron una de las vacunas chinas contra el covid-19',
#  'La alcaldesa de Miami-Dade tiene covid-19 y entró en cuarentena',
#  'Unilever prueba en Nueva Zelanda la semana laboral de cuatro días con el 100% del salario',
#  'Los momentos más emblemáticos de “La Noche del 10″, el increíble programa de Diego Maradona',
#  'Rosa Parks: la modista que dijo no, se quedó sentada en el colectivo en el lugar “reservado para blancos” y desató una revolución',
#  'Elecciones en Estados Unidos: Wisconsin confirmó la victoria de Joe Biden tras el recuento de votos',
#  'El Reino Unido investiga el papel de la contaminación en la muerte de una niña: el caso podría sentar un precedente',
#  'Chile respondió a la acusación de China de un supuesto hallazgo de COVID-19 en uno de sus productos exportados',
#  'Una nueva ausencia de Lionel Messi en Champions League: la explicación de Ronald Koeman',
#  'Renunció Scott Atlas, el asesor especial de Donald Trump sobre el coronavirus',
#  'Leopoldo López dijo que espera que Joe Biden apoye “un cambio de régimen en Venezuela”',
#  'Tras más de un año de detención ilegal, la Justicia chavista liberó a dos acusados del “Golpe Azul” contra Nicolás Maduro',
#  'Elecciones en Venezuela: una vieja película',
#  'Cómo opera CEIEC, la empresa estatal china que ayuda a la dictadura de Nicolás Maduro a censurar medios digitales',
#  'Nicolás Maduro levantó el toque de queda fronterizo y flexibilizó el confinamiento por el “espíritu de la Navidad”',
#  'Venezuela allana organización benéfica alimentaria, lo que interrumpe las comidas destinadas para niños',
#  'Los homenajes que ni el más maradoniano hubiese pensado',
#  'Aún no cumplen 30 años y ya ahorran para el retiro: cómo y por qué',
#  'La Reserva Federal de EEUU advirtió que se moderó la reactivación económica y ve perspectivas “extraordinariamente inciertas”',
#  'Premio Gabo: el equipo de periodistas de Radio Cooperativa de Chile se quedó con el “Reconocimiento a la Excelencia”',
#  'La historia de la mujer que amó al Chapo Guzmán y terminó en el área de enfermos mentales de un reclusorio varonil',
#  'Se cierra el cerco sobre el “Mencho”: 309 operadores del CJNG han sido detenidos en los últimos diez meses',
#  'Un sicario vestido de payaso y un tiroteo en el carnaval de Mazatlán: la caída de los Arellano Félix',
#  'Maradona o la razón del mito plebeyo irrepetible',
#  'Tyson confesó que fumó marihuana en su regreso al boxeo y habló sobre los efectos que le causa sobre el ring',
#  'Lewis Hamilton tiene coronavirus y se perderá el GP de Sakhir de la F1: “Por favor cuiden a los suyos”',
#  'River buscará su pase a los cuartos de final ante un diezmado Athletico Paranaense: tiene 15 bajas',
#  'Manchester City, Bayern Múnich, Real Madrid y Liverpool: hora, TV y agenda de partidos de la Champions',
#  'El impactante trueque de figuras que estudian PSG y Juventus',
#  'Según una revisión de estudios, algunos pacientes con COVID-19 pueden contagiar hasta 20 días',
#  'Vitamina D: qué dice la evidencia científica sobre esta poderosa herramienta para la salud',
#  'Un estudio clínico catalán descartó a la hidroxicloroquina para el tratamiento del COVID-19',
#  'El régimen de Cuba rechazó dialogar con los artistas que se manifestaron por la libertad de expresión',
#  'Colombia reafirma el compromiso que asumió en París y va por más',
#  'Alemania planea una devolución de impuestos para los empleados que realizan teletrabajo por la pandemia de coronavirus',
#  'Cómo logró Jeff Bezos construir su imperio, en primera persona',
#  '“Wolf Warrior”: qué esconde el brutal ataque de un alto funcionario de Xi Jinping a Australia y por qué América Latina debe estar preparada',
#  '120 años sin Oscar Wilde: la genialidad, la literatura provocadora y la muerte',
#  'El príncipe heredero de Japón aprobó la boda de su hija Mako con un ciudadano común con problemas económicos',
#  '“Pandemic” fue elegida como la Palabra del Año del diccionario Merriam-Webster',
#  'Cómo configurar el Asistente de Google desde tu celular para que te salude, te diga el clima o te agende una cita',
#  'El Reino Unido prohibirá a las compañías de telecomunicaciones instalar equipos de 5G de Huawei a partir de septiembre de 2021',
#  'Llamativo cambio en el perfil de la cuenta oficial de Instagram de Diego Maradona: dejó de ser “en memoria de”',
#  'Cuáles son los 100 mejores inventos de 2020, según la revista Time',
#  'MÁS LEIDAS AMÉRICA',
#  'De Ellen Page a Elliot: se hizo célebre por la película “Juno” y acaba de anunciar que es trans',
#  'Asedio en la puerta de su casa, llamados permanentes y críticas: la pesadilla que vive el dueño de la camiseta que usó Maradona ante Inglaterra en el ’86',
#  'Insólito combate de MMA en Rusia: una luchadora venció por nocaut a un youtuber de 240 kilos',
#  'Los homenajes que ni el más maradoniano hubiese pensado',
#  'Hugh Grant confesó por qué Hollywood le cerró las puertas por casi una década: “Hice el tonto en una película”',
#  'El rol de las embajadas extranjeras ante la criminalización de las libertades en Cuba',
#  'De Obama a Biden: dilemas de política exterior',
#  'El Papa Francisco y la necesidad actual de la ternura',
#  'Los tatuajes del “amor eterno” por Diego Maradona',
#  'Un incendio destrozó una propiedad de la familia de Jennifer Lawrence',
#  'La encendida defensa de Jon Voight a Donald Trump lo vuelve a alejar de su hija Angelina Jolie',
#  'Glenn Close afirmó que Gwyneth Paltrow no merecía el Oscar que ganó por “Shakespeare In Love”',
#  'Las mejores fotos del eclipse lunar con el que Buenos Aires despidió noviembre',
#  'En fotos: así despidió México a Maradona',
#  'El entierro de Diego Maradona en fotos: quiénes participaron de la ceremonia',
#  'VENEZUELA',
#  'EEUU',
#  'MÉXICO',
#  'COLOMBIA',
#  'ENTRETENIMIENTO',
#  'DEPORTES',
#  'ÚLTIMAS NOTICIAS',
#  'TENDENCIAS']

# %%
def ibae():
  list = []
  for x in range(0,len(tit)):
      list.append(tit[x].get_text(strip=True))
  return list

# %%
ibae()
# Out:
# ['EEUU pidió a sus ciudadanos que eviten viajar a México, ante el fuerte aumento de contagios de COVID-19',
#  'Por primera vez en la historia, el 50% de la publicidad fue destinada a medios digitales',
#  'De Ellen Page a Elliot: se hizo célebre por la película "Juno" y acaba de anunciar que es trans',
#  'Boris Johnson enfrenta una rebelión parlamentaria por las restricciones en el Reino Unido para frenar el covid-19',
#  'Un conductor embistió con su vehículo a los transeúntes de una calle peatonal en Alemania: 4 muertos, entre ellos un bebé',
#  'Arabia Saudita autorizó que los aviones comerciales israelíes utilicen su espacio aéreo en vuelo hacia Emiratos Árabes Unidos',
#  'Hugh Grant confesó por qué Hollywood le cerró las puertas por casi una década: “Hice el tonto en una película”',
#  'Un youtuber saltó de un puente para sumar seguidores en su canal y terminó con el cráneo fracturado',
#  'Asedio en la puerta de su casa, llamados permanentes y críticas: la pesadilla que vive el dueño de la camiseta que usó Maradona ante Inglaterra en el ’86',
#  'La monumental caricatura del dibujante inglés David Squires que rinde tributo a Maradona: Fiorito, la gloria, el ocaso y la eternidad',
#  'El regalo que guardará por siempre y la última conversación que tuvieron: las emotivas palabras de Ronaldo tras la muerte de Maradona',
#  'Los archivos de Wuhan: cómo el régimen chino ocultó el impacto del coronavirus en el inicio de la pandemia',
#  'Conmoción en Houston: hallaron muerta a la influencer de Instagram Alexis Sharkey',
#  'Insólito combate de MMA en Rusia: una luchadora venció por nocaut a un youtuber de 240 kilos',
#  'Wall Street inicia diciembre con una sólida alza tras cerrar su mejor mes desde 1987',
#  'Real Madrid cae ante el Shakhtar en Ucrania y pone en peligro su clasificación',
#  'Caso Ahmadreza Djalali: el régimen de Irán se prepara para ejecutar a un experto en medicina',
#  'Un fisicoculturista ruso se casó con su muñeca sexual: “Nuestro romance floreció durante la cuarentena”',
#  'Pfizer solicitó a la Unión Europea la autorización de emergencia para su vacuna contra el coronavirus',
#  'Dos conductas que la OMS desaconsejó de cara a las Fiestas de fin de año',
#  'La historia detrás del abrazo de un médico a un desconsolado paciente de covid-19 que conmovió a EEUU en el Día de Acción de Gracias',
#  'Director de Operaciones Técnicas de Moderna: “Vamos a llevar la vacuna a donde se necesite”',
#  'Coronavirus: 16 certezas que hoy tienen los médicos y es importante conocer',
#  '\ufeffKim Jong-un, su familia y los funcionarios de alto rango de Corea del Norte ya recibieron una de las vacunas chinas contra el covid-19',
#  'La alcaldesa de Miami-Dade tiene covid-19 y entró en cuarentena',
#  'Unilever prueba en Nueva Zelanda la semana laboral de cuatro días con el 100% del salario',
#  'Los momentos más emblemáticos de “La Noche del 10″, el increíble programa de Diego Maradona',
#  'Rosa Parks: la modista que dijo no, se quedó sentada en el colectivo en el lugar “reservado para blancos” y desató una revolución',
#  'Elecciones en Estados Unidos: Wisconsin confirmó la victoria de Joe Biden tras el recuento de votos',
#  'El Reino Unido investiga el papel de la contaminación en la muerte de una niña: el caso podría sentar un precedente',
#  'Chile respondió a la acusación de China de un supuesto hallazgo de COVID-19 en uno de sus productos exportados',
#  'Una nueva ausencia de Lionel Messi en Champions League: la explicación de Ronald Koeman',
#  'Renunció Scott Atlas, el asesor especial de Donald Trump sobre el coronavirus',
#  'Leopoldo López dijo que espera que Joe Biden apoye “un cambio de régimen en Venezuela”',
#  'Tras más de un año de detención ilegal, la Justicia chavista liberó a dos acusados del “Golpe Azul” contra Nicolás Maduro',
#  'Elecciones en Venezuela: una vieja película',
#  'Cómo opera CEIEC, la empresa estatal china que ayuda a la dictadura de Nicolás Maduro a censurar medios digitales',
#  'Nicolás Maduro levantó el toque de queda fronterizo y flexibilizó el confinamiento por el “espíritu de la Navidad”',
#  'Venezuela allana organización benéfica alimentaria, lo que interrumpe las comidas destinadas para niños',
#  'Los homenajes que ni el más maradoniano hubiese pensado',
#  'Aún no cumplen 30 años y ya ahorran para el retiro: cómo y por qué',
#  'La Reserva Federal de EEUU advirtió que se moderó la reactivación económica y ve perspectivas “extraordinariamente inciertas”',
#  'Premio Gabo: el equipo de periodistas de Radio Cooperativa de Chile se quedó con el “Reconocimiento a la Excelencia”',
#  'La historia de la mujer que amó al Chapo Guzmán y terminó en el área de enfermos mentales de un reclusorio varonil',
#  'Se cierra el cerco sobre el “Mencho”: 309 operadores del CJNG han sido detenidos en los últimos diez meses',
#  'Un sicario vestido de payaso y un tiroteo en el carnaval de Mazatlán: la caída de los Arellano Félix',
#  'Maradona o la razón del mito plebeyo irrepetible',
#  'Tyson confesó que fumó marihuana en su regreso al boxeo y habló sobre los efectos que le causa sobre el ring',
#  'Lewis Hamilton tiene coronavirus y se perderá el GP de Sakhir de la F1: “Por favor cuiden a los suyos”',
#  'River buscará su pase a los cuartos de final ante un diezmado Athletico Paranaense: tiene 15 bajas',
#  'Manchester City, Bayern Múnich, Real Madrid y Liverpool: hora, TV y agenda de partidos de la Champions',
#  'El impactante trueque de figuras que estudian PSG y Juventus',
#  'Según una revisión de estudios, algunos pacientes con COVID-19 pueden contagiar hasta 20 días',
#  'Vitamina D: qué dice la evidencia científica sobre esta poderosa herramienta para la salud',
#  'Un estudio clínico catalán descartó a la hidroxicloroquina para el tratamiento del COVID-19',
#  'El régimen de Cuba rechazó dialogar con los artistas que se manifestaron por la libertad de expresión',
#  'Colombia reafirma el compromiso que asumió en París y va por más',
#  'Alemania planea una devolución de impuestos para los empleados que realizan teletrabajo por la pandemia de coronavirus',
#  'Cómo logró Jeff Bezos construir su imperio, en primera persona',
#  '“Wolf Warrior”: qué esconde el brutal ataque de un alto funcionario de Xi Jinping a Australia y por qué América Latina debe estar preparada',
#  '120 años sin Oscar Wilde: la genialidad, la literatura provocadora y la muerte',
#  'El príncipe heredero de Japón aprobó la boda de su hija Mako con un ciudadano común con problemas económicos',
#  '“Pandemic” fue elegida como la Palabra del Año del diccionario Merriam-Webster',
#  'Cómo configurar el Asistente de Google desde tu celular para que te salude, te diga el clima o te agende una cita',
#  'El Reino Unido prohibirá a las compañías de telecomunicaciones instalar equipos de 5G de Huawei a partir de septiembre de 2021',
#  'Llamativo cambio en el perfil de la cuenta oficial de Instagram de Diego Maradona: dejó de ser “en memoria de”',
#  'Cuáles son los 100 mejores inventos de 2020, según la revista Time',
#  'MÁS LEIDAS AMÉRICA',
#  'De Ellen Page a Elliot: se hizo célebre por la película “Juno” y acaba de anunciar que es trans',
#  'Asedio en la puerta de su casa, llamados permanentes y críticas: la pesadilla que vive el dueño de la camiseta que usó Maradona ante Inglaterra en el ’86',
#  'Insólito combate de MMA en Rusia: una luchadora venció por nocaut a un youtuber de 240 kilos',
#  'Los homenajes que ni el más maradoniano hubiese pensado',
#  'Hugh Grant confesó por qué Hollywood le cerró las puertas por casi una década: “Hice el tonto en una película”',
#  'El rol de las embajadas extranjeras ante la criminalización de las libertades en Cuba',
#  'De Obama a Biden: dilemas de política exterior',
#  'El Papa Francisco y la necesidad actual de la ternura',
#  'Los tatuajes del “amor eterno” por Diego Maradona',
#  'Un incendio destrozó una propiedad de la familia de Jennifer Lawrence',
#  'La encendida defensa de Jon Voight a Donald Trump lo vuelve a alejar de su hija Angelina Jolie',
#  'Glenn Close afirmó que Gwyneth Paltrow no merecía el Oscar que ganó por “Shakespeare In Love”',
#  'Las mejores fotos del eclipse lunar con el que Buenos Aires despidió noviembre',
#  'En fotos: así despidió México a Maradona',
#  'El entierro de Diego Maradona en fotos: quiénes participaron de la ceremonia',
#  'VENEZUELA',
#  'EEUU',
#  'MÉXICO',
#  'COLOMBIA',
#  'ENTRETENIMIENTO',
#  'DEPORTES',
#  'ÚLTIMAS NOTICIAS',
#  'TENDENCIAS']
